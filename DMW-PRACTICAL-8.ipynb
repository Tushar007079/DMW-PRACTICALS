# %% [markdown]
# # ***Student Name: Tushar Panchal***
#
# # ***En. No. : 21162101014***
#
# # ***Branch: CBA***
#
# # ***Batch:  61***
#
# # ***Subject: DMW (Data Mining & Warehousing)***

# %% [markdown]
# # **PRACTICAL 8**
# #  Naive Bayes Classification

# %% [markdown]
# The Iris flower data set is a multivariate data set introduced by the British statistician and biologist Ronald Fisher in his 1936 paper The use of
# multiple measurements in taxonomic problems. It is sometimes called Anderson's Iris data set because Edgar Anderson collected the data to
# quantify the morphologic variation of Iris flowers of three related species. The data set consists of 50 samples from each of three species of
# Iris (Iris Setosa, Iris virginica, and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and
# petals, in centimeters.
#
# This dataset became a typical test case for many statistical classification techniques. Kindly implement the Naive Bayes Classification for
# famous Iris Flower. Dataset that consists of 3 classes of flowers. In this, there are 4 independent variables namely the, sepal_length,
# sepal_width, petal_length and petal_width. The dependent variable is the species which we will predict using the four independent features of
# the flowers.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import io

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e89210e6-9880-4772-a4a2-cc517bcef1c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e89210e6-9880-4772-a4a2-cc517bcef1c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(io.BytesIO(uploaded['gene_expression.csv']))

# %%
df.head()
# Out:
#    Gene One  Gene Two  Cancer Present
# 0       4.3       3.9               1
# 1       2.5       6.3               0
# 2       5.7       3.9               1
# 3       6.1       6.2               0
# 4       7.4       3.4               1

# %%
sns.scatterplot(data=df,x='Gene One',y='Gene Two')
# Out:
# <Axes: xlabel='Gene One', ylabel='Gene Two'>

# %%
sns.scatterplot(data=df,x='Gene One',y='Gene Two',hue='Cancer Present')
# Out:
# <Axes: xlabel='Gene One', ylabel='Gene Two'>

# %%
sns.scatterplot(data=df,x='Gene One',y='Gene Two',hue='Cancer Present',alpha=0.6)
# Out:
# <Axes: xlabel='Gene One', ylabel='Gene Two'>

# %%
sns.scatterplot(data=df,x='Gene One',y='Gene Two',hue='Cancer Present',alpha=0.6)
plt.xlim(2,6)
plt.ylim(3,10)
plt.legend(labels=["Cancer Present","Cancer Absent"])

# %%
len(df)
# Out:
# 3000

# %%
sns.pairplot(data=df,hue="Cancer Present")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop("Cancer Present",axis=1)
y=df['Cancer Present']

# %%
X_train, X_test, y_train , y_test= train_test_split(X,y,test_size=0.33,random_state=42)

# %%
Scaler=StandardScaler()

# %%
Scaler_X_train=Scaler.fit_transform(X_train)
Scaler_X_train=Scaler.fit_transform(X_test)

# %%
data=pd.concat([X_test,y_test],axis=1)

# %%
len(data)
# Out:
# 990

# %%
print(data)
# Out:
#       Gene One  Gene Two  Cancer Present
# 1801       7.7       4.1               1
# 1190       5.3       2.8               1
# 1817       8.9       4.2               1
# 251        3.3       5.7               0
# 2505       4.7       7.3               0
# ...        ...       ...             ...
# 2468       8.8       5.4               1
# 2013       7.0       3.3               1
# 714        8.2       3.5               1
# 803        7.0       6.4               0
# 2008       4.6       4.8               1
#
# [990 rows x 3 columns]

# %%
sns.scatterplot(data=data,x='Gene One',y='Gene Two',hue='Cancer Present',alpha = 0.6)
# Out:
# <Axes: xlabel='Gene One', ylabel='Gene Two'>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-0985c7eb-946c-4310-bb65-4ca3436099a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0985c7eb-946c-4310-bb65-4ca3436099a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv(io.BytesIO(uploaded['iris.csv']))
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sns.scatterplot(data=df,x='sepal_length', y='petal_length',hue='species',alpha=0.7)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# %%
X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = df['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9866666666666667
